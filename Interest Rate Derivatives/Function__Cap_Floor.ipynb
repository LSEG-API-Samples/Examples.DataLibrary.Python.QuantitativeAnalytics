# %% [markdown]
# # Refinitiv Data Platform Library for Python
# ## Function - IPA - Cap Floor

# %% [markdown]
# This notebook demonstrates how to price Cap Floor using the Instrument Pricing Analytics (IPA) and the Refinitiv Data Libraries.
#
# ##### Learn more
#
# To learn more about the Refinitiv Data Library for Python please join the Refinitiv Developer Community. By [registering](https://developers.refinitiv.com/iam/register) and [logging](https://developers.refinitiv.com/content/devportal/en_us/initCookie.html) into the Refinitiv Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start),
#  [Tutorials](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/tutorials),
#  [Documentation](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/documentation)
#  and much more.
#
# You may also visit the [API Playground](https://apidocs.refinitiv.com/Apps/ApiDocs) to get more examples, find  end points and download Swagger files
#
# ##### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [Refinitiv Data Q&A Forum](https://community.developers.refinitiv.com/spaces/321/index.html).
# The Refinitiv Developer Community will be happy to help.

# %% [markdown]
# ## Import the library and connect to Refinitiv Data Libraries

# %%
import refinitiv.data as rd
import refinitiv.data.content.ipa.financial_contracts as rdf
from refinitiv.data.content.ipa.financial_contracts import cap_floor

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the refinitiv-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
rd.open_session()
# Out:
# <refinitiv.data.session.Definition object at 0x104449970 {name='workspace'}>

# %% [markdown]
# ## Cap Floor Pricing

# %% [markdown]
# ### Single

# %%
response = cap_floor.Definition(
    notional_ccy="EUR",
    index_name="EURIBOR",
    start_date="2019-02-11",
    amortization_schedule=[
        cap_floor.AmortizationItem(
            start_date="2021-02-12",
            end_date="2021-02-12",
            amount=100000,
            amortization_type=cap_floor.AmortizationType.SCHEDULE,
        ),
        cap_floor.AmortizationItem(
            start_date="2021-02-11",
            end_date="2021-02-11",
            amount=-100000,
            amortization_type=cap_floor.AmortizationType.SCHEDULE,
        ),
    ],
    tenor="5Y",
    buy_sell="Sell",
    notional_amount=10000000,
    interest_payment_frequency=cap_floor.Frequency.MONTHLY,
    cap_strike_percent=1

).get_data()

response.data.df
# Out:
#    InstrumentTag  InstrumentDescription CallPut ValuationDate MarketDataDate  \
# 0           <NA>  SHORT EUR 1.0000% CAP     CAP    2023-03-07     2023-03-07
#
#    StartDate    EndDate Tenor InterestPaymentFrequency IndexResetFrequency  \
# 0 2019-02-11 2024-02-12    5Y                  Monthly             Monthly
#
#    ... ImpliedVolatilityBp DeltaPercent ForwardDeltaPercent  \
# 0  ...          144.005797    -0.979296           -0.996442
#
#    DV01AmountInDealCcy  GammaAmountInDealCcy VegaAmountInDealCcy  \
# 0          -859.416953              0.091977           -7.430101
#
#    ThetaAmountInDealCcy  ErrorCode  ErrorMessage  ProcessingInformation
# 0             41.284572
#
# [1 rows x 29 columns]

# %% [markdown]
# ### Multiple

# %%
response = rdf.Definitions(
    universe=[
        cap_floor.Definition(
            notional_ccy="EUR",
            index_name="EURIBOR",
            start_date="2019-02-11",
            amortization_schedule=[
                cap_floor.AmortizationItem(
                    start_date="2021-02-12",
                    end_date="2021-02-12",
                    amount=100000,
                    amortization_type=cap_floor.AmortizationType.SCHEDULE,
                ),
                cap_floor.AmortizationItem(
                    start_date="2021-02-11",
                    end_date="2021-02-11",
                    amount=-100000,
                    amortization_type=cap_floor.AmortizationType.SCHEDULE,
                ),
            ],
            tenor="5Y",
            buy_sell="Sell",
            notional_amount=10000000,
            interest_payment_frequency=cap_floor.Frequency.MONTHLY,
            cap_strike_percent=1),
        cap_floor.Definition(
            notional_ccy="EUR",
            index_name="EURIBOR",
            start_date="2019-02-11",
            amortization_schedule=[
                cap_floor.AmortizationItem(
                    start_date="2021-02-12",
                    end_date="2021-02-12",
                    amount=100000,
                    amortization_type=cap_floor.AmortizationType.SCHEDULE,
                ),
                cap_floor.AmortizationItem(
                    start_date="2021-02-11",
                    end_date="2021-02-11",
                    amount=-100000,
                    amortization_type=cap_floor.AmortizationType.SCHEDULE,
                ),
            ],
            tenor="5Y",
            buy_sell="Sell",
            notional_amount=10000000,
            interest_payment_frequency=cap_floor.Frequency.MONTHLY,
            cap_strike_percent=1)
    ]
).get_data()

response.data.df
# Out:
#    InstrumentTag  InstrumentDescription CallPut ValuationDate MarketDataDate  \
# 0           <NA>  SHORT EUR 1.0000% CAP     CAP    2023-03-07     2023-03-07
# 1           <NA>  SHORT EUR 1.0000% CAP     CAP    2023-03-07     2023-03-07
#
#    StartDate    EndDate Tenor InterestPaymentFrequency IndexResetFrequency  \
# 0 2019-02-11 2024-02-12    5Y                  Monthly             Monthly
# 1 2019-02-11 2024-02-12    5Y                  Monthly             Monthly
#
#    ... ImpliedVolatilityBp DeltaPercent ForwardDeltaPercent  \
# 0  ...          144.005797    -0.979296           -0.996442
# 1  ...          144.005797    -0.979296           -0.996442
#
#    DV01AmountInDealCcy  GammaAmountInDealCcy VegaAmountInDealCcy  \
# 0          -859.416953              0.091977           -7.430101
# 1          -859.416953              0.091977           -7.430101
#
#    ThetaAmountInDealCcy  ErrorCode  ErrorMessage  ProcessingInformation
# 0             41.284572
# 1             41.284572
#
# [2 rows x 29 columns]

# %% [markdown]
# ### Fields selection

# %%
response = cap_floor.Definition(

    notional_ccy="EUR",
    index_name="EURIBOR",
    start_date="2019-02-11",
    amortization_schedule=[
        cap_floor.AmortizationItem(
            start_date="2021-02-12",
            end_date="2021-02-12",
            amount=100000,
            amortization_type=cap_floor.AmortizationType.SCHEDULE,
        ),
        cap_floor.AmortizationItem(
            start_date="2021-02-11",
            end_date="2021-02-11",
            amount=-100000,
            amortization_type=cap_floor.AmortizationType.SCHEDULE,
        ),
    ],
    tenor="5Y",
    buy_sell="Sell",
    notional_amount=10000000,
    interest_payment_frequency=cap_floor.Frequency.MONTHLY,
    cap_strike_percent=1,
    fields=[
        "InstrumentTag",
        "InstrumentDescription",
        "FixedRate",
        "MarketValueInDealCcy",
        "MarketValueInReportCcy",
        "ErrorMessage"
    ]
).get_data()

response.data.df
# Out:
#    InstrumentTag  InstrumentDescription  FixedRate  MarketValueInDealCcy  \
# 0           <NA>  SHORT EUR 1.0000% CAP       <NA>        -245668.184307
#
#    MarketValueInReportCcy ErrorMessage
# 0                    <NA>

# %% [markdown]
# ### Global calculation parameters

# %%
response = rdf.Definitions(

    universe=[cap_floor.Definition(
        notional_ccy="EUR",
        index_name="EURIBOR",
        start_date="2019-02-11",
        amortization_schedule=[
            cap_floor.AmortizationItem(
                start_date="2021-02-12",
                end_date="2021-02-12",
                amount=100000,
                amortization_type=cap_floor.AmortizationType.SCHEDULE,
            ),
            cap_floor.AmortizationItem(
                start_date="2021-02-11",
                end_date="2021-02-11",
                amount=-100000,
                amortization_type=cap_floor.AmortizationType.SCHEDULE,
            ),
        ],
        tenor="5Y",
        buy_sell="Sell",
        notional_amount=10000000,
        interest_payment_frequency=cap_floor.Frequency.MONTHLY,
        cap_strike_percent=1)
    ],
    pricing_parameters=cap_floor.PricingParameters(
        skip_first_cap_floorlet=False,
        valuation_date="2020-02-07"
    ),
).get_data()

response.data.df
# Out:
#    InstrumentTag  InstrumentDescription CallPut ValuationDate MarketDataDate  \
# 0           <NA>  SHORT EUR 1.0000% CAP     CAP    2020-02-07     2020-02-07
#
#    StartDate    EndDate Tenor InterestPaymentFrequency IndexResetFrequency  \
# 0 2019-02-11 2024-02-12    5Y                  Monthly             Monthly
#
#    ... ImpliedVolatilityBp DeltaPercent ForwardDeltaPercent  \
# 0  ...           50.970276    -0.033973           -0.033499
#
#    DV01AmountInDealCcy  GammaAmountInDealCcy VegaAmountInDealCcy  \
# 0           -136.22184             -3.019291         -469.573889
#
#    ThetaAmountInDealCcy  ErrorCode  ErrorMessage  \
# 0              7.767209
#
#                                ProcessingInformation
# 0  The following global parameter is invalid: ski...
#
# [1 rows x 29 columns]

# %% [markdown]
# ### Global & Individual calculation parameters

# %%
response = rdf.Definitions(

    universe=[cap_floor.Definition(
        notional_ccy="EUR",
        index_name="EURIBOR",
        start_date="2019-02-11",
        amortization_schedule=[
            cap_floor.AmortizationItem(
                start_date="2021-02-12",
                end_date="2021-02-12",
                amount=100000,
                amortization_type=cap_floor.AmortizationType.SCHEDULE,
            ),
            cap_floor.AmortizationItem(
                start_date="2021-02-11",
                end_date="2021-02-11",
                amount=-100000,
                amortization_type=cap_floor.AmortizationType.SCHEDULE,
            ),
        ],
        tenor="5Y",
        buy_sell="Sell",
        notional_amount=10000000,
        interest_payment_frequency=cap_floor.Frequency.MONTHLY,
        cap_strike_percent=1,
        pricing_parameters=cap_floor.PricingParameters(
            skip_first_cap_floorlet=True,
            valuation_date="2020-02-07")
    )],
    pricing_parameters=cap_floor.PricingParameters(
        valuation_date="2020-02-07"),
).get_data()

response.data.df
# Out:
#    InstrumentTag  InstrumentDescription CallPut ValuationDate MarketDataDate  \
# 0           <NA>  SHORT EUR 1.0000% CAP     CAP    2020-02-07     2020-02-07
#
#    StartDate    EndDate Tenor InterestPaymentFrequency IndexResetFrequency  \
# 0 2019-02-11 2024-02-12    5Y                  Monthly             Monthly
#
#    ... ImpliedVolatilityBp DeltaPercent ForwardDeltaPercent  \
# 0  ...           50.970276    -0.033973           -0.033499
#
#    DV01AmountInDealCcy  GammaAmountInDealCcy VegaAmountInDealCcy  \
# 0           -136.22184             -3.019291         -469.573889
#
#    ThetaAmountInDealCcy  ErrorCode  ErrorMessage  ProcessingInformation
# 0              7.767209
#
# [1 rows x 29 columns]

# %% [markdown]
# ## Close the default session

# %%
rd.close_session()
